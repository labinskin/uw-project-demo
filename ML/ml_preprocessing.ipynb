# %% [markdown]
# # Machine Learning Preprocessing
# This notebook draws data from the AWS database into two pandas dataframes. The two dataframes are then merged and prepared for unsupervised machine learning. The output from this notebook is a CSV.
#
# For futher detail into the database please see the Data directory.
#
# For further detail into the exploratory analysis of this dataset please see the E_A directory.
#
# To see the machine learning model please see the machine_learning_final notebook.
#
#
# ## Imports Needed

# %%
# Initial imports
import pandas as pd
import psycopg2
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, MetaData, Table

# %% [markdown]
# ## Load The Data

# %%
#Create Connection to AWS
database_url = 'postgresql://postgres:awspassword@wisconsin-crime-data.c24ehsgyv1el.us-east-1.rds.amazonaws.com:5432/wisconsin-crime-data'
engine= create_engine(database_url)
connection = engine.connect()
population_data_df = pd.read_sql_table('ml_data', engine)

# %%
population_data_df.head(5)
# Out:
#   state    county  ue_rural_urban_continuum_code_2013  \
# 0    WI     Adams                                   8
# 1    WI   Ashland                                   7
# 2    WI    Barron                                   6
# 3    WI  Bayfield                                   8
# 4    WI     Brown                                   2
#
#    ue_urban_influence_code_2013  ue_metro_2013  ue_civilian_labor_force_2000  \
# 0                             6              0                          8892
# 1                            11              0                          8904
# 2                             6              0                         24959
# 3                             6              0                          7715
# 4                             2              1                        131182
#
#    ue_employed_2000  ue_unemployed_2000  ue_unemployment_rate_2000  \
# 0              8502                 390                        4.4
# 1              8434                 470                        5.3
# 2             23987                 972                        3.9
# 3              7309                 406                        5.3
# 4            127485                3697                        2.8
#
#    ue_civilian_labor_force_2001  ...  \
# 0                          9093  ...
# 1                          9129  ...
# 2                         25291  ...
# 3                          7948  ...
# 4                        132306  ...
#
#    percent_some_college_or_associates_degree_2000  \
# 0                                            24.8
# 1                                            27.1
# 2                                            28.0
# 3                                            31.2
# 4                                            28.9
#
#    percent_bachelors_degree_or_higher_2000  \
# 0                                     10.0
# 1                                     16.5
# 2                                     14.9
# 3                                     21.6
# 4                                     22.5
#
#    less_than_a_high_school_diploma_2015_19  high_school_diploma_only_2015_19  \
# 0                                     2013                              6856
# 1                                      828                              3946
# 2                                     3162                             11654
# 3                                      567                              3351
# 4                                    13787                             52162
#
#    some_college_or_associates_degree_2015_19  \
# 0                                       5006
# 1                                       3772
# 2                                      10801
# 3                                       4005
# 4                                      55776
#
#    bachelors_degree_or_higher_2015_19  \
# 0                                2231
# 1                                2114
# 2                                6644
# 3                                3576
# 4                               52901
#
#    percent_less_than_a_high_school_diploma_2015_19  \
# 0                                             12.5
# 1                                              7.8
# 2                                              9.8
# 3                                              4.9
# 4                                              7.9
#
#    percent_high_school_diploma_only_2015_19  \
# 0                                      42.6
# 1                                      37.0
# 2                                      36.1
# 3                                      29.1
# 4                                      29.9
#
#    percent_some_college_or_associates_degree_2015_19  \
# 0                                               31.1
# 1                                               35.4
# 2                                               33.5
# 3                                               34.8
# 4                                               31.9
#
#    percent_bachelors_degree_or_higher_2015_19
# 0                                        13.9
# 1                                        19.8
# 2                                        20.6
# 3                                        31.1
# 4                                        30.3
#
# [5 rows x 278 columns]

# %%
# Load second table as DataFrame
offenses_data_df = pd.read_sql_table('offenses_by_county', engine)
offenses_data_df.head(5)
# Out:
#   county offense_description  year  sum_offense_count
# 0  Adams  Aggravated Assault  2020                 38
# 1  Adams  Aggravated Assault  2019                 23
# 2  Adams  Aggravated Assault  2018                 31
# 3  Adams               Arson  2020                  0
# 4  Adams               Arson  2019                  3

# %% [markdown]
# ## Use Pandas to Prepare Data for Machine Learning

# %%
# Drop the year column
offenses_data_df = offenses_data_df.drop('year',axis=1)

# %%
# Offense descriptions as columns
offenses_data_df= offenses_data_df.groupby(['county','offense_description'], as_index=False).sum().pivot('county','offense_description')
offenses_data_df
# Out:
#                      sum_offense_count                          \
# offense_description Aggravated Assault Arson Burglary Homicide
# county
# Adams                               92     6      343        0
# Ashland                            111     8      116        1
# Barron                             101     4      155        5
# Bayfield                            73     4      120        1
# Brown                             1460    50     1077       13
# ...                                ...   ...      ...      ...
# Waukesha                           537    19      965       19
# Waupaca                            182     5      268        3
# Waushara                            64     2      115        1
# Winnebago                          655    22      964        8
# Wood                                65     8      376        4
#
#                                                         \
# offense_description Human Trafficking - Commercial Sex
# county
# Adams                                                1
# Ashland                                              0
# Barron                                               0
# Bayfield                                             0
# Brown                                               44
# ...                                                ...
# Waukesha                                             1
# Waupaca                                              0
# Waushara                                             0
# Winnebago                                            5
# Wood                                                 0
#
#                                                                              \
# offense_description Human Trafficking - Involuntary Servitude Larceny Theft
# county
# Adams                                                       0           559
# Ashland                                                     0           757
# Barron                                                      0           975
# Bayfield                                                    0           225
# Brown                                                       1          7593
# ...                                                       ...           ...
# Waukesha                                                    0          9094
# Waupaca                                                     0          1518
# Waushara                                                    0           768
# Winnebago                                                   3          5371
# Wood                                                        0          2979
#
#                                                                      \
# offense_description Motor Vehicle Theft Rape - revised 2017 Robbery
# county
# Adams                                33                  20       4
# Ashland                              83                  16       3
# Barron                               72                  56       1
# Bayfield                             30                   8       0
# Brown                               507                 392     169
# ...                                 ...                 ...     ...
# Waukesha                            474                 196     142
# Waupaca                              77                  72       4
# Waushara                             29                  18       2
# Winnebago                           364                 213      74
# Wood                                137                 140       8
#
#
# offense_description Simple Assault
# county
# Adams                          453
# Ashland                        124
# Barron                         318
# Bayfield                        53
# Brown                         3759
# ...                            ...
# Waukesha                      1693
# Waupaca                        423
# Waushara                       212
# Winnebago                     2191
# Wood                           740
#
# [72 rows x 11 columns]

# %%
# Condense column index
offenses_data_df.columns = [' '.join(col).strip() for col in offenses_data_df.columns.values]
offenses_data_df
# Out:
#            sum_offense_count Aggravated Assault  sum_offense_count Arson  \
# county
# Adams                                        92                        6
# Ashland                                     111                        8
# Barron                                      101                        4
# Bayfield                                     73                        4
# Brown                                      1460                       50
# ...                                         ...                      ...
# Waukesha                                    537                       19
# Waupaca                                     182                        5
# Waushara                                     64                        2
# Winnebago                                   655                       22
# Wood                                         65                        8
#
#            sum_offense_count Burglary  sum_offense_count Homicide  \
# county
# Adams                             343                           0
# Ashland                           116                           1
# Barron                            155                           5
# Bayfield                          120                           1
# Brown                            1077                          13
# ...                               ...                         ...
# Waukesha                          965                          19
# Waupaca                           268                           3
# Waushara                          115                           1
# Winnebago                         964                           8
# Wood                              376                           4
#
#            sum_offense_count Human Trafficking - Commercial Sex  \
# county
# Adams                                                      1
# Ashland                                                    0
# Barron                                                     0
# Bayfield                                                   0
# Brown                                                     44
# ...                                                      ...
# Waukesha                                                   1
# Waupaca                                                    0
# Waushara                                                   0
# Winnebago                                                  5
# Wood                                                       0
#
#            sum_offense_count Human Trafficking - Involuntary Servitude  \
# county
# Adams                                                      0
# Ashland                                                    0
# Barron                                                     0
# Bayfield                                                   0
# Brown                                                      1
# ...                                                      ...
# Waukesha                                                   0
# Waupaca                                                    0
# Waushara                                                   0
# Winnebago                                                  3
# Wood                                                       0
#
#            sum_offense_count Larceny Theft  \
# county
# Adams                                  559
# Ashland                                757
# Barron                                 975
# Bayfield                               225
# Brown                                 7593
# ...                                    ...
# Waukesha                              9094
# Waupaca                               1518
# Waushara                               768
# Winnebago                             5371
# Wood                                  2979
#
#            sum_offense_count Motor Vehicle Theft  \
# county
# Adams                                         33
# Ashland                                       83
# Barron                                        72
# Bayfield                                      30
# Brown                                        507
# ...                                          ...
# Waukesha                                     474
# Waupaca                                       77
# Waushara                                      29
# Winnebago                                    364
# Wood                                         137
#
#            sum_offense_count Rape - revised 2017  sum_offense_count Robbery  \
# county
# Adams                                         20                          4
# Ashland                                       16                          3
# Barron                                        56                          1
# Bayfield                                       8                          0
# Brown                                        392                        169
# ...                                          ...                        ...
# Waukesha                                     196                        142
# Waupaca                                       72                          4
# Waushara                                      18                          2
# Winnebago                                    213                         74
# Wood                                         140                          8
#
#            sum_offense_count Simple Assault
# county
# Adams                                   453
# Ashland                                 124
# Barron                                  318
# Bayfield                                 53
# Brown                                  3759
# ...                                     ...
# Waukesha                               1693
# Waupaca                                 423
# Waushara                                212
# Winnebago                              2191
# Wood                                    740
#
# [72 rows x 11 columns]

# %%
# Clean up those column names
offenses_data_df.reset_index(inplace=True)
offenses_data_df['county'] = offenses_data_df['county'].astype(str)
offenses_data_df.head()
# Out:
#      county  sum_offense_count Aggravated Assault  sum_offense_count Arson  \
# 0     Adams                                    92                        6
# 1   Ashland                                   111                        8
# 2    Barron                                   101                        4
# 3  Bayfield                                    73                        4
# 4     Brown                                  1460                       50
#
#    sum_offense_count Burglary  sum_offense_count Homicide  \
# 0                         343                           0
# 1                         116                           1
# 2                         155                           5
# 3                         120                           1
# 4                        1077                          13
#
#    sum_offense_count Human Trafficking - Commercial Sex  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                 44
#
#    sum_offense_count Human Trafficking - Involuntary Servitude  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#    sum_offense_count Larceny Theft  sum_offense_count Motor Vehicle Theft  \
# 0                              559                                     33
# 1                              757                                     83
# 2                              975                                     72
# 3                              225                                     30
# 4                             7593                                    507
#
#    sum_offense_count Rape - revised 2017  sum_offense_count Robbery  \
# 0                                     20                          4
# 1                                     16                          3
# 2                                     56                          1
# 3                                      8                          0
# 4                                    392                        169
#
#    sum_offense_count Simple Assault
# 0                               453
# 1                               124
# 2                               318
# 3                                53
# 4                              3759

# %%
# Create a toatl offense count column
sum_column = offenses_data_df['sum_offense_count Aggravated Assault'] + offenses_data_df['sum_offense_count Arson'] + offenses_data_df['sum_offense_count Burglary'] + offenses_data_df['sum_offense_count Homicide'] + offenses_data_df['sum_offense_count Human Trafficking - Commercial Sex'] + offenses_data_df['sum_offense_count Human Trafficking - Involuntary Servitude'] + offenses_data_df['sum_offense_count Larceny Theft'] + offenses_data_df['sum_offense_count Motor Vehicle Theft'] + offenses_data_df['sum_offense_count Rape - revised 2017'] + offenses_data_df['sum_offense_count Robbery'] + offenses_data_df['sum_offense_count Simple Assault']
offenses_data_df["total_offenses"] = sum_column

# %%
# Looky looky
offenses_data_df
# Out:
#        county  sum_offense_count Aggravated Assault  sum_offense_count Arson  \
# 0       Adams                                    92                        6
# 1     Ashland                                   111                        8
# 2      Barron                                   101                        4
# 3    Bayfield                                    73                        4
# 4       Brown                                  1460                       50
# ..        ...                                   ...                      ...
# 67   Waukesha                                   537                       19
# 68    Waupaca                                   182                        5
# 69   Waushara                                    64                        2
# 70  Winnebago                                   655                       22
# 71       Wood                                    65                        8
#
#     sum_offense_count Burglary  sum_offense_count Homicide  \
# 0                          343                           0
# 1                          116                           1
# 2                          155                           5
# 3                          120                           1
# 4                         1077                          13
# ..                         ...                         ...
# 67                         965                          19
# 68                         268                           3
# 69                         115                           1
# 70                         964                           8
# 71                         376                           4
#
#     sum_offense_count Human Trafficking - Commercial Sex  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                  44
# ..                                                ...
# 67                                                  1
# 68                                                  0
# 69                                                  0
# 70                                                  5
# 71                                                  0
#
#     sum_offense_count Human Trafficking - Involuntary Servitude  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   1
# ..                                                ...
# 67                                                  0
# 68                                                  0
# 69                                                  0
# 70                                                  3
# 71                                                  0
#
#     sum_offense_count Larceny Theft  sum_offense_count Motor Vehicle Theft  \
# 0                               559                                     33
# 1                               757                                     83
# 2                               975                                     72
# 3                               225                                     30
# 4                              7593                                    507
# ..                              ...                                    ...
# 67                             9094                                    474
# 68                             1518                                     77
# 69                              768                                     29
# 70                             5371                                    364
# 71                             2979                                    137
#
#     sum_offense_count Rape - revised 2017  sum_offense_count Robbery  \
# 0                                      20                          4
# 1                                      16                          3
# 2                                      56                          1
# 3                                       8                          0
# 4                                     392                        169
# ..                                    ...                        ...
# 67                                    196                        142
# 68                                     72                          4
# 69                                     18                          2
# 70                                    213                         74
# 71                                    140                          8
#
#     sum_offense_count Simple Assault  total_offenses
# 0                                453            1511
# 1                                124            1219
# 2                                318            1687
# 3                                 53             514
# 4                               3759           15065
# ..                               ...             ...
# 67                              1693           13140
# 68                               423            2552
# 69                               212            1211
# 70                              2191            9870
# 71                               740            4457
#
# [72 rows x 13 columns]

# %%
# Merge the two dataFrames together
merged_df = pd.merge(population_data_df, offenses_data_df, how='outer', on=['county'])
merged_df
# Out:
#    state     county  ue_rural_urban_continuum_code_2013  \
# 0     WI      Adams                                   8
# 1     WI    Ashland                                   7
# 2     WI     Barron                                   6
# 3     WI   Bayfield                                   8
# 4     WI      Brown                                   2
# ..   ...        ...                                 ...
# 67    WI   Waukesha                                   1
# 68    WI    Waupaca                                   6
# 69    WI   Waushara                                   6
# 70    WI  Winnebago                                   3
# 71    WI       Wood                                   4
#
#     ue_urban_influence_code_2013  ue_metro_2013  ue_civilian_labor_force_2000  \
# 0                              6              0                          8892
# 1                             11              0                          8904
# 2                              6              0                         24959
# 3                              6              0                          7715
# 4                              2              1                        131182
# ..                           ...            ...                           ...
# 67                             1              1                        210606
# 68                             6              0                         27822
# 69                             6              0                         11801
# 70                             2              1                         89669
# 71                             5              0                         40907
#
#     ue_employed_2000  ue_unemployed_2000  ue_unemployment_rate_2000  \
# 0               8502                 390                        4.4
# 1               8434                 470                        5.3
# 2              23987                 972                        3.9
# 3               7309                 406                        5.3
# 4             127485                3697                        2.8
# ..               ...                 ...                        ...
# 67            204958                5648                        2.7
# 68             26899                 923                        3.3
# 69             11313                 488                        4.1
# 70             87231                2438                        2.7
# 71             39344                1563                        3.8
#
#     ue_civilian_labor_force_2001  ...  sum_offense_count Burglary  \
# 0                           9093  ...                         343
# 1                           9129  ...                         116
# 2                          25291  ...                         155
# 3                           7948  ...                         120
# 4                         132306  ...                        1077
# ..                           ...  ...                         ...
# 67                        211507  ...                         965
# 68                         28148  ...                         268
# 69                         12366  ...                         115
# 70                         91472  ...                         964
# 71                         41138  ...                         376
#
#     sum_offense_count Homicide  \
# 0                            0
# 1                            1
# 2                            5
# 3                            1
# 4                           13
# ..                         ...
# 67                          19
# 68                           3
# 69                           1
# 70                           8
# 71                           4
#
#     sum_offense_count Human Trafficking - Commercial Sex  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                  44
# ..                                                ...
# 67                                                  1
# 68                                                  0
# 69                                                  0
# 70                                                  5
# 71                                                  0
#
#     sum_offense_count Human Trafficking - Involuntary Servitude  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   1
# ..                                                ...
# 67                                                  0
# 68                                                  0
# 69                                                  0
# 70                                                  3
# 71                                                  0
#
#     sum_offense_count Larceny Theft  sum_offense_count Motor Vehicle Theft  \
# 0                               559                                     33
# 1                               757                                     83
# 2                               975                                     72
# 3                               225                                     30
# 4                              7593                                    507
# ..                              ...                                    ...
# 67                             9094                                    474
# 68                             1518                                     77
# 69                              768                                     29
# 70                             5371                                    364
# 71                             2979                                    137
#
#     sum_offense_count Rape - revised 2017  sum_offense_count Robbery  \
# 0                                      20                          4
# 1                                      16                          3
# 2                                      56                          1
# 3                                       8                          0
# 4                                     392                        169
# ..                                    ...                        ...
# 67                                    196                        142
# 68                                     72                          4
# 69                                     18                          2
# 70                                    213                         74
# 71                                    140                          8
#
#     sum_offense_count Simple Assault  total_offenses
# 0                                453            1511
# 1                                124            1219
# 2                                318            1687
# 3                                 53             514
# 4                               3759           15065
# ..                               ...             ...
# 67                              1693           13140
# 68                               423            2552
# 69                               212            1211
# 70                              2191            9870
# 71                               740            4457
#
# [72 rows x 290 columns]

# %%
# Make a CSV to show your friends, or keep for future use...
# Output new CSV
output_file_path = "merged_data.csv"
merged_df.to_csv(output_file_path, index=False)

# %%
#Drop labels, we already know this data trends to state and county
ml_data_df = merged_df.drop(['state', 'county'], axis=1)
ml_data_df
# Out:
#     ue_rural_urban_continuum_code_2013  ue_urban_influence_code_2013  \
# 0                                    8                             6
# 1                                    7                            11
# 2                                    6                             6
# 3                                    8                             6
# 4                                    2                             2
# ..                                 ...                           ...
# 67                                   1                             1
# 68                                   6                             6
# 69                                   6                             6
# 70                                   3                             2
# 71                                   4                             5
#
#     ue_metro_2013  ue_civilian_labor_force_2000  ue_employed_2000  \
# 0               0                          8892              8502
# 1               0                          8904              8434
# 2               0                         24959             23987
# 3               0                          7715              7309
# 4               1                        131182            127485
# ..            ...                           ...               ...
# 67              1                        210606            204958
# 68              0                         27822             26899
# 69              0                         11801             11313
# 70              1                         89669             87231
# 71              0                         40907             39344
#
#     ue_unemployed_2000  ue_unemployment_rate_2000  \
# 0                  390                        4.4
# 1                  470                        5.3
# 2                  972                        3.9
# 3                  406                        5.3
# 4                 3697                        2.8
# ..                 ...                        ...
# 67                5648                        2.7
# 68                 923                        3.3
# 69                 488                        4.1
# 70                2438                        2.7
# 71                1563                        3.8
#
#     ue_civilian_labor_force_2001  ue_employed_2001  ue_unemployed_2001  ...  \
# 0                           9093              8632                 461  ...
# 1                           9129              8592                 537  ...
# 2                          25291             24093                1198  ...
# 3                           7948              7501                 447  ...
# 4                         132306            127088                5218  ...
# ..                           ...               ...                 ...  ...
# 67                        211507            203911                7596  ...
# 68                         28148             26860                1288  ...
# 69                         12366             11715                 651  ...
# 70                         91472             88058                3414  ...
# 71                         41138             39174                1964  ...
#
#     sum_offense_count Burglary  sum_offense_count Homicide  \
# 0                          343                           0
# 1                          116                           1
# 2                          155                           5
# 3                          120                           1
# 4                         1077                          13
# ..                         ...                         ...
# 67                         965                          19
# 68                         268                           3
# 69                         115                           1
# 70                         964                           8
# 71                         376                           4
#
#     sum_offense_count Human Trafficking - Commercial Sex  \
# 0                                                   1
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                  44
# ..                                                ...
# 67                                                  1
# 68                                                  0
# 69                                                  0
# 70                                                  5
# 71                                                  0
#
#     sum_offense_count Human Trafficking - Involuntary Servitude  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   1
# ..                                                ...
# 67                                                  0
# 68                                                  0
# 69                                                  0
# 70                                                  3
# 71                                                  0
#
#     sum_offense_count Larceny Theft  sum_offense_count Motor Vehicle Theft  \
# 0                               559                                     33
# 1                               757                                     83
# 2                               975                                     72
# 3                               225                                     30
# 4                              7593                                    507
# ..                              ...                                    ...
# 67                             9094                                    474
# 68                             1518                                     77
# 69                              768                                     29
# 70                             5371                                    364
# 71                             2979                                    137
#
#     sum_offense_count Rape - revised 2017  sum_offense_count Robbery  \
# 0                                      20                          4
# 1                                      16                          3
# 2                                      56                          1
# 3                                       8                          0
# 4                                     392                        169
# ..                                    ...                        ...
# 67                                    196                        142
# 68                                     72                          4
# 69                                     18                          2
# 70                                    213                         74
# 71                                    140                          8
#
#     sum_offense_count Simple Assault  total_offenses
# 0                                453            1511
# 1                                124            1219
# 2                                318            1687
# 3                                 53             514
# 4                               3759           15065
# ..                               ...             ...
# 67                              1693           13140
# 68                               423            2552
# 69                               212            1211
# 70                              2191            9870
# 71                               740            4457
#
# [72 rows x 288 columns]

# %%
# Make a CSV to show your friends, or keep for future use...
# Output new CSV
output_file_path = "ml_data.csv"
ml_data_df.to_csv(output_file_path, index=False)
